# %%
import pandas as pd

# 读取分号分隔的 CSV 文件
df = pd.read_csv("gas_oil_tasks_for_mapping_rus.csv", sep=';')

# 显示数据的前几行，确认读取是否正确
print(df.head())
# Out:
#    task_id                                          task_name measurement  \
# 0        1                    Расчистка от лесорастительности          га
# 1        2  Расчистка от лесорастительности при строительс...          км
# 2        3  Расчистка от лесорастительности при строительс...          км
# 3        4  Расчистка от лесорастительности при строительс...          км
# 4        5  Расчистка от лесорастительности при строительс...          км
#
#                                             subtasks
# 0  Состав работ:\n01. Вырубка кустарника и подрос...
# 1  Состав работ:\n01. Вырубка кустарника и подрос...
# 2  Состав работ:\n01. Вырубка кустарника и подрос...
# 3  Состав работ:\n01. Вырубка кустарника и подрос...
# 4  Состав работ:\n01. Вырубка кустарника и подрос...

# %%
df
# Out:
#       task_id                                          task_name measurement  \
# 0           1                    Расчистка от лесорастительности          га
# 1           2  Расчистка от лесорастительности при строительс...          км
# 2           3  Расчистка от лесорастительности при строительс...          км
# 3           4  Расчистка от лесорастительности при строительс...          км
# 4           5  Расчистка от лесорастительности при строительс...          км
# ...       ...                                                ...         ...
# 1237     1238                      Демонтаж водоподающей станции          шт
# 1238     1239                            Демонтаж КПП (шлагбаум)          шт
# 1239     1240                        Демонтаж ВЖК из вагон-домов        к.м.
# 1240     1241                 Демонтаж ВЖК комбинированного типа        к.м.
# 1241     1242  Демонтаж деревянной кровельной стропильной сис...          м3
#
# ...

# %%
# 重新保存为逗号分隔的 CSV 文件
df.to_csv("converted_file.csv", index=False, sep=',')
